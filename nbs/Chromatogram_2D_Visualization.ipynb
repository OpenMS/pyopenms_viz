# %%
# %load_ext autoreload
# %autoreload 2
# Out:
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload

# %%
import os
import numpy as np
import pandas as pd
from bokeh.io import output_notebook, show
from pyopenms_viz.ChromatogramPlotter import plotChromatogram

output_notebook()
# Out:
# <div class="bk-root">
#         <a href="https://bokeh.org" target="_blank" class="bk-logo bk-logo-small bk-logo-notebook"></a>
#         <span id="11945">Loading BokehJS ...</span>
#     </div>

# %%
df_featmap = pd.read_csv("../test/test_data/ionMobilityTestFeatureDf.tsv", sep="\t")
df_featmap.head()
# Out:
#    native_id  ms_level  precursor_mz          mz           rt        im  \
# 0        NaN         1      642.3295  642.334187  6225.005106  0.900254
# 1        NaN         1      642.3295  642.334187  6225.005106  0.969271
# 2        NaN         2      642.3295  504.262011  6225.110817  0.935281
# 3        NaN         2      642.3295  504.262011  6225.110817  1.025902
# 4        NaN         2      642.3295  504.262011  6225.110817  0.926001
#
#           int Annotation  product_mz
# 0   76.000460       prec    642.3295
# 1  153.011280       prec    642.3295
# 2   68.001520       y4^1    504.2664
# 3   41.000328       y4^1    504.2664
# 4   43.000782       y4^1    504.2664

# %%
df_feat = pd.read_csv("../test/test_data/ionMobilityTest2-diannReport.tsv", sep="\t")
df_feat.head()
# Out:
#    Unnamed: 0               Run            Protein.Ids Modified.Sequence  \
# 0           1  ionMobilityTest2  sp|Q07021|C1QBP_HUMAN       AFVDFLSDEIK
#
#   Stripped.Sequence  Precursor.Charge  PG.Quantity  apexIntensity          RT  \
# 0       AFVDFLSDEIK                 2    1137201.5      1137201.5  6241.44882
#
#      leftWidth  rightWidth    IM  q_value       PEP
# 0  6236.052702  6248.63205  0.98  0.00008  0.002026

# %% [markdown]
# # Bokeh

# %%
p_hm = plotChromatogram(df_featmap, plot_type = "heatmap", engine="BOKEH")
# Out:
#   <div class="bk-root" id="a41f663c-9ea6-45d2-bc2d-cb3b5e50ca8c" data-root-id="11947"></div>

# %% [markdown]
# ## Add 1D marginal plots to the heatmap

# %%
p_hm = plotChromatogram(df_featmap, plot_type = "heatmap", add_marginals=True, engine="BOKEH")
# Out:
#   <div class="bk-root" id="77ca62a4-152d-4028-bd07-87335b4aa82d" data-root-id="13065"></div>

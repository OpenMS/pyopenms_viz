# %% [markdown]
# # Getting Started

# %% [markdown]
# <a href="https://notebooks.gesis.org/binder/v2/gh/OpenMS/pyopenms_viz/main?filepath=docs/Getting Started.ipynb" target="_blank">
#     <img src="https://mybinder.org/badge_logo.svg" alt="Launch on Binder" style="width: 150px;"/>
# </a>

# %% [markdown]
# This tutorial demonstrates the basic usage of `pyopenms_viz`, a plotting interface built on top of pandas for generating mass spectrometry plots like spectra, chromatograms, and peak maps.
#
# `pyopenms_viz` allows users to visualize mass spectrometry data with minimal effort, making it ideal for software developers, bioinformaticians, and experimental scientists.
#
# **Steps:**
# 1. Load raw mass spectrometry data into a pandas DataFrame.
# 2. Plot the data using the `plot()` method with various backends and options.
#
# **Requirements:**
# - `pyopenms` (v3.2.0)
# - Visualization backends: matplotlib, bokeh, or plotly

# %%
   from urllib.request import urlretrieve

   gh = "https://raw.githubusercontent.com/OpenMS/pyopenms-docs/master"
   urlretrieve(
       gh + "/src/data/PrecursorPurity_input.mzML", "test.mzML"
   )
   urlretrieve(
       gh + "/src/data/YIC(Carbamidomethyl)DNQDTISSK.mzML", "YIC(Carbamidomethyl)DNQDTISSK.mzML"
   )
# Out:
# ('YIC(Carbamidomethyl)DNQDTISSK.mzML',
#  <http.client.HTTPMessage at 0x72eca47e7290>)

# %%
from urllib.request import urlretrieve

gh = "https://raw.githubusercontent.com/OpenMS/pyopenms-docs/master"
urlretrieve(
       gh + "/src/data/PrecursorPurity_input.mzML", "test.mzML"
)
urlretrieve(
       gh + "/src/data/YIC(Carbamidomethyl)DNQDTISSK.mzML", "YIC(Carbamidomethyl)DNQDTISSK.mzML"
)
# Out:
# ('YIC(Carbamidomethyl)DNQDTISSK.mzML',
#  <http.client.HTTPMessage at 0x72eca4808740>)

# %% [markdown]
# ## **Load Data into a Pandas DataFrame**

# %% [markdown]
# One key element to `pyopenms-viz` is the ability to process expanding off the pandas DataFrame plotting interface. This means that the plotting can be extended to any package as long as the data can be formatted into a pandas dataframe in long format. For this tutorial we will use `pyopenms` for formatting. Examples using different packages can be found here.

# %% [markdown]
# ## Plot a Spectrum

# %%
# !pip install pyopenms # install pyopenms if not already installed
# Out:
# Requirement already satisfied: pyopenms in /home/joshua/mambaforge/envs/pyopenms-viz/lib/python3.12/site-packages (3.2.0)
# Requirement already satisfied: numpy<=1.26.4 in /home/joshua/mambaforge/envs/pyopenms-viz/lib/python3.12/site-packages (from pyopenms) (1.26.4)
# Requirement already satisfied: pandas in /home/joshua/mambaforge/envs/pyopenms-viz/lib/python3.12/site-packages (from pyopenms) (2.2.3)
# Requirement already satisfied: matplotlib>=3.5 in /home/joshua/mambaforge/envs/pyopenms-viz/lib/python3.12/site-packages (from pyopenms) (3.9.2)
# Requirement already satisfied: contourpy>=1.0.1 in /home/joshua/mambaforge/envs/pyopenms-viz/lib/python3.12/site-packages (from matplotlib>=3.5->pyopenms) (1.3.0)
# Requirement already satisfied: cycler>=0.10 in /home/joshua/mambaforge/envs/pyopenms-viz/lib/python3.12/site-packages (from matplotlib>=3.5->pyopenms) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in /home/joshua/mambaforge/envs/pyopenms-viz/lib/python3.12/site-packages (from matplotlib>=3.5->pyopenms) (4.54.1)
# Requirement already satisfied: kiwisolver>=1.3.1 in /home/joshua/mambaforge/envs/pyopenms-viz/lib/python3.12/site-packages (from matplotlib>=3.5->pyopenms) (1.4.7)
# Requirement already satisfied: packaging>=20.0 in /home/joshua/mambaforge/envs/pyopenms-viz/lib/python3.12/site-packages (from matplotlib>=3.5->pyopenms) (24.1)
# Requirement already satisfied: pillow>=8 in /home/joshua/mambaforge/envs/pyopenms-viz/lib/python3.12/site-packages (from matplotlib>=3.5->pyopenms) (11.0.0)
# Requirement already satisfied: pyparsing>=2.3.1 in /home/joshua/mambaforge/envs/pyopenms-viz/lib/python3.12/site-packages (from matplotlib>=3.5->pyopenms) (3.2.0)
# Requirement already satisfied: python-dateutil>=2.7 in /home/joshua/mambaforge/envs/pyopenms-viz/lib/python3.12/site-packages (from matplotlib>=3.5->pyopenms) (2.9.0.post0)
# Requirement already satisfied: pytz>=2020.1 in /home/joshua/mambaforge/envs/pyopenms-viz/lib/python3.12/site-packages (from pandas->pyopenms) (2024.2)
# Requirement already satisfied: tzdata>=2022.7 in /home/joshua/mambaforge/envs/pyopenms-viz/lib/python3.12/site-packages (from pandas->pyopenms) (2024.2)
# Requirement already satisfied: six>=1.5 in /home/joshua/mambaforge/envs/pyopenms-viz/lib/python3.12/site-packages (from python-dateutil>=2.7->matplotlib>=3.5->pyopenms) (1.16.0)

# %%
import pyopenms as oms

# Load the raw mass spectrometry data
exp = oms.MSExperiment()
oms.MzMLFile().load("test.mzML", exp)

# Convert data to pandas DataFrame
exp_df = exp.get_df(long=True)

# Display the first few rows of the DataFrame
exp_df.head()
# Out:
#             RT          mz          inty
# 0  3610.811768  354.457886  151031.03125
# 1  3610.811768  354.720947  280613.87500
# 2  3610.811768  354.888855  335459.40625
# 3  3610.811768  355.069855  803474.50000
# 4  3610.811768  355.224487  329080.53125

# %%
# Filter the data to retention time RT = 3610.811768
spectrum_3610_rt = exp_df[exp_df['RT'] == 3610.811768]

# Display the filtered DataFrame
spectrum_3610_rt.head()

# Plot the spectrum using the Bokeh backend
plot = spectrum_3610_rt.plot(kind='spectrum', backend='ms_bokeh', x='mz', y='inty')
# Out:
#     <style>
#         .bk-notebook-logo {
#             display: block;
#             width: 20px;
#             height: 20px;
#             background-image: url(data:image/png;base64,...);
#         }
#     </style>
#     <div>
#         <a href="https://bokeh.org" target="_blank" class="bk-notebook-logo"></a>
#         <span id="a5a08cb9-9559-4dbd-87d9-62fa80dc0c54">Loading BokehJS ...</span>
#     </div>
#   <div id="eba98f0b-0550-480e-a464-c89b692b3337" data-root-id="p1001" style="display: contents;"></div>
